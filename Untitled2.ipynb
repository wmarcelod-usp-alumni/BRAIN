# %%
import importlib
import subprocess
import sys

# Função para instalar pacotes se não estiverem instalados
def install_and_import(package):
    try:
        importlib.import_module(package)
    except ImportError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
    finally:
        globals()[package] = importlib.import_module(package)

# Verificar e instalar pacotes necessários
install_and_import('pandas')

import pandas as pd

# Carregar os dados do CSV
file_path = 'dados.csv'
gps_data = pd.read_csv(file_path, delimiter=';')

# Renomear a coluna "LONGTITUDE" para "LONGITUDE"
gps_data.rename(columns={'LONGTITUDE': 'LONGITUDE'}, inplace=True)

# Ordenar os dados por timestamp
gps_data = gps_data.sort_values(by='SECONDS')

# Calcular o intervalo de timestamp que representa 80% dos dados
total_data_points = len(gps_data)
start_index = int(0.1 * total_data_points)
end_index = int(0.9 * total_data_points)
start_timestamp = gps_data['SECONDS'].iloc[start_index]
end_timestamp = gps_data['SECONDS'].iloc[end_index]

# Filtrar os dados para manter apenas os timestamps dentro desse intervalo
filtered_data = gps_data[(gps_data['SECONDS'] >= start_timestamp) & (gps_data['SECONDS'] <= end_timestamp)]

# Obter lista única de unidades e seus sensores
units = filtered_data['UNITS'].unique()
sensors_by_unit = {unit: filtered_data[filtered_data['UNITS'] == unit]['PID'].unique() for unit in units}

# Imprimir a lista de sensores agrupados por unidade
for unit, sensors in sensors_by_unit.items():
    print(f"Unit: {unit}")
    for sensor in sensors:
        print(f"  Sensor: {sensor}")

# Se precisar exportar essa lista para um arquivo
with open('sensors_by_unit.txt', 'w') as f:
    for unit, sensors in sensors_by_unit.items():
        f.write(f"Unit: {unit}\n")
        for sensor in sensors:
            f.write(f"  Sensor: {sensor}\n")
# Out:
# Unit: km
#   Sensor: Distância para esvaziar
#   Sensor: Distância percorrida
#   Sensor: Distância percorrida (total)
# Unit: rpm
#   Sensor: RPM do motor
#   Sensor: RPM do motor x1000
#   Sensor: [MCU] GMCU Motor Speed
#   Sensor: [MCU] TMCU Motor Speed
# Unit: R$
#   Sensor: Preço do combustível usado
#   Sensor: Preço do combustível usado (total)
# Unit: hp
#   Sensor: Potência instantânea do motor (baseado no consumo de combustível)
#   Sensor: HV EV Battery Power
#   Sensor: [BMS] Pack 10s Recharge Power Limit
#   Sensor: [BMS] Pack 10s Discharge Power Limit
#   Sensor: [BMS] Pack 2s Discharge Power Limit
#   Sensor: [BMS] Pack 2s Recharge Power Limit
# Unit: L/100km
#   Sensor: Consumo médio de combustível (l/100km) 10 sec
#   Sensor: Consumo médio de combustível (l/100km)
#   Sensor: Consumo médio de combustível (l/100km) (total)
#   Sensor: Consumo instantâneo de combustível (l/100km)
# Unit: L
#   Sensor: Combustível usado
#   Sensor: Combustível usado (total)
#   Sensor: Nível de combustível (V)
#   Sensor: Espaço livre no tanque de combustível
# Unit: L/h
#   Sensor: Consumo instantâneo de combustível (l/h)
# Unit: m
#   Sensor: Altitude (GPS)
# Unit: km/h
#   Sensor: Velocidade (GPS)
#   Sensor: Velocidade média (GPS)
#   Sensor: Velocidade do veículo
#   Sensor: Velocidade média
# Unit: A
#   Sensor: Corrente do sistema de bateria híbrida / EV
#   Sensor: [BMS] Bus current
#   Sensor: [BMS] Pack discharge current limit
#   Sensor: [BMS] Pack Recharge current limit
# Unit: V
#   Sensor: Tensão do sistema de bateria híbrida / EV
#   Sensor: [ECM] Knock sensor reference Cyl.1
#   Sensor: [ECM] Knock sensor reference Cyl.2
#   Sensor: [ECM] Knock sensor reference Cyl.3
#   Sensor: [ECM] Knock sensor reference Cyl.4
#   Sensor: [BMS] Pack Voltage
#   Sensor: [BMS] Total summ of all cell voltages
# Unit: %
#   Sensor: Nível de combustível (%)
#   Sensor: Posição da borboleta de admissão
#   Sensor: [ECM] Turbocharger target opening
#   Sensor: [ECM] Turbocharger actual opening
#   Sensor: [BMS] Batt. SOC
#   Sensor: [BMS] Max cell SoC
#   Sensor: [BMS] Min cell SoC
#   Sensor: [BMS] Pack SoH
# Unit: g
#   Sensor: Aceleração
# Unit: km/kWh
#   Sensor: EV Instant Energy Consumption
# Unit: kWh/100km
#   Sensor: EV Instant Energy Consumption [kWh/100km]
# Unit: kPa
#   Sensor: Pressão absoluta do coletor de
# admissão
#   Sensor: [ECM] Actual boost pressure
#   Sensor: [ECM] Target boost pressure
#   Sensor: [ECM] Turbocharger pre-model pressure
#   Sensor: [TPMS] Rear left tire pressure
#   Sensor: [TPMS] Rear right tire pressure
#   Sensor: [TPMS] Front right tire pressure
#   Sensor: [TPMS] Front left tire pressure
# Unit: bar
#   Sensor: Boost calculado
# Unit: mA
#   Sensor: Sensor de oxigênio 1 Banda Larga Corrente (mA)
# Unit: nan
# Unit: ℃
#   Sensor: [ECM] Model oil temperature
#   Sensor: [ECM] Turbocharger pre-model temperature
#   Sensor: [BMS] Module temperature average
#   Sensor: [BMS] Module temperature maximum
#   Sensor: [BMS] Module temperature minimum
#   Sensor: [BMS] Pack Loop Inlet Temperature
#   Sensor: [BMS] Module #1 Temperature
#   Sensor: [BMS] Module #2 Temperature
#   Sensor: [BMS] Module #3 Temperature
#   Sensor: [BMS] Module #4 Temperature
#   Sensor: [BMS] Module #5 Temperature
#   Sensor: [BMS] Module #6 Temperature
#   Sensor: [MCU] GMCU Motor Temperature 1
#   Sensor: [MCU] GMCU Motor Temperature 2
#   Sensor: [MCU] TMCU Invertor Temperature
#   Sensor: [MCU] TMCU Motor Temperature #1
#   Sensor: [MCU] TMCU Motor Temperature #2
#   Sensor: [TPMS] Rear right tire temperature
#   Sensor: [TPMS] Rear left tire temperature
#   Sensor: [TPMS] Front left tire temperature
#   Sensor: [TPMS] Front right tire temperature
#   Sensor: [HVAC] Front evaporator temperature
#   Sensor: [HVAC] Front in-car temperature
# Unit: °
#   Sensor: [ECM] Actual intake VVT opening
#   Sensor: [ECM] Target intake VVT opening
#   Sensor: [ECM] Knock retard Cyl.1
#   Sensor: [ECM] Knock retard Cyl.2
#   Sensor: [ECM] Knock retard Cyl.3
#   Sensor: [ECM] Knock retard Cyl.4
# Unit: Ah
#   Sensor: [BMS] Battery pack accumulated charge #1
#   Sensor: [BMS] Battery pack accumulated charge #2
# Unit: sec.
#   Sensor: [BMS] BMS last sleep duration time
# Unit: mV
#   Sensor: [BMS] Cell voltage Max
#   Sensor: [BMS] Cell voltage Min
#   Sensor: [BMS] Battery Cell #68
#   Sensor: [BMS] Battery Cell #67
#   Sensor: [BMS] Battery Cell #66
#   Sensor: [BMS] Battery Cell #65
#   Sensor: [BMS] Battery Cell #64
#   Sensor: [BMS] Battery Cell #63
#   Sensor: [BMS] Battery Cell #62
#   Sensor: [BMS] Battery Cell #61
#   Sensor: [BMS] Battery Cell #60
#   Sensor: [BMS] Battery Cell #69
#   Sensor: [BMS] Battery Cell #48
#   Sensor: [BMS] Battery Cell #57
#   Sensor: [BMS] Battery Cell #56
#   Sensor: [BMS] Battery Cell #55
#   Sensor: [BMS] Battery Cell #54
#   Sensor: [BMS] Battery Cell #53
#   Sensor: [BMS] Battery Cell #52
#   Sensor: [BMS] Battery Cell #51
#   Sensor: [BMS] Battery Cell #50
#   Sensor: [BMS] Battery Cell #49
#   Sensor: [BMS] Battery Cell #58
#   Sensor: [BMS] Battery Cell #59
#   Sensor: [BMS] Battery Cell #70
#   Sensor: [BMS] Battery Cell #72
#   Sensor: [BMS] Battery Cell #92
#   Sensor: [BMS] Battery Cell #91
#   Sensor: [BMS] Battery Cell #90
#   Sensor: [BMS] Battery Cell #89
#   Sensor: [BMS] Battery Cell #88
#   Sensor: [BMS] Battery Cell #87
#   Sensor: [BMS] Battery Cell #86
#   Sensor: [BMS] Battery Cell #85
#   Sensor: [BMS] Battery Cell #83
#   Sensor: [BMS] Battery Cell #82
#   Sensor: [BMS] Battery Cell #81
#   Sensor: [BMS] Battery Cell #80
#   Sensor: [BMS] Battery Cell #79
#   Sensor: [BMS] Battery Cell #78
#   Sensor: [BMS] Battery Cell #77
#   Sensor: [BMS] Battery Cell #76
#   Sensor: [BMS] Battery Cell #75
#   Sensor: [BMS] Battery Cell #74
#   Sensor: [BMS] Battery Cell #73
#   Sensor: [BMS] Battery Cell #71
#   Sensor: [BMS] Battery Cell #47
#   Sensor: [BMS] Battery Cell #84
#   Sensor: [BMS] Battery Cell #45
#   Sensor: [BMS] Battery Cell #20
#   Sensor: [BMS] Battery Cell #19
#   Sensor: [BMS] Battery Cell #18
#   Sensor: [BMS] Battery Cell #17
#   Sensor: [BMS] Battery Cell #15
#   Sensor: [BMS] Battery Cell #14
#   Sensor: [BMS] Battery Cell #13
#   Sensor: [BMS] Battery Cell #12
#   Sensor: [BMS] Battery Cell #11
#   Sensor: [BMS] Battery Cell #21
#   Sensor: [BMS] Battery Cell #10
#   Sensor: [BMS] Battery Cell #46
#   Sensor: [BMS] Battery Cell #08
#   Sensor: [BMS] Battery Cell #07
#   Sensor: [BMS] Battery Cell #06
#   Sensor: [BMS] Battery Cell #05
#   Sensor: [BMS] Battery Cell #04
#   Sensor: [BMS] Battery Cell #03
#   Sensor: [BMS] Battery Cell #02
#   Sensor: [BMS] Battery Cell #01
#   Sensor: [BMS] Battery Cell #09
#   Sensor: [BMS] Battery Cell #22
#   Sensor: [BMS] Battery Cell #16
#   Sensor: [BMS] Battery Cell #24
#   Sensor: [BMS] Battery Cell #44
#   Sensor: [BMS] Battery Cell #43
#   Sensor: [BMS] Battery Cell #42
#   Sensor: [BMS] Battery Cell #41
#   Sensor: [BMS] Battery Cell #23
#   Sensor: [BMS] Battery Cell #39
#   Sensor: [BMS] Battery Cell #38
#   Sensor: [BMS] Battery Cell #37
#   Sensor: [BMS] Battery Cell #36
#   Sensor: [BMS] Battery Cell #35
#   Sensor: [BMS] Battery Cell #40
#   Sensor: [BMS] Battery Cell #33
#   Sensor: [BMS] Battery Cell #32
#   Sensor: [BMS] Battery Cell #31
#   Sensor: [BMS] Battery Cell #30
#   Sensor: [BMS] Battery Cell #29
#   Sensor: [BMS] Battery Cell #34
#   Sensor: [BMS] Battery Cell #28
#   Sensor: [BMS] Battery Cell #27
#   Sensor: [BMS] Battery Cell #26
#   Sensor: [BMS] Battery Cell #25
# Unit: kWh
#   Sensor: [BMS] Pack SoE
# Unit: N⋅m
#   Sensor: [MCU] GMCU Torque Max
#   Sensor: [MCU] GMCU Torque Min
# Unit: m/sec.
#   Sensor: [ESP] Rear left wheel speed
#   Sensor: [ESP] Front left wheel speed
#   Sensor: [ESP] Front right wheel speed
#   Sensor: [ESP] Rear right wheel speed
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[1], line 52
#      50 with open('sensors_by_unit.txt', 'w') as f:
#      51     for unit, sensors in sensors_by_unit.items():
# ---> 52         f.write(f"Unit: {unit}\n")
#      53         for sensor in sensors:
#      54             f.write(f"  Sensor: {sensor}\n")
#
# File ~\anaconda3\lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2103' in position 6: character maps to <undefined>
